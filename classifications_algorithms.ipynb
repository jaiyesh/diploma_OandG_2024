# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
phi_s = np.abs(np.random.normal(0.25,0.01,300))
swc_s = np.abs(np.random.normal(0.1,0.01,300))
k_s = 8.58102*(phi_s**(4.4))/(swc_s**2)

# %%
phi_l = np.abs(np.random.normal(0.20,0.01,300))
swc_l = np.abs(np.random.normal(0.1,0.01,300))
k_l = 8.58102*(phi_l**(4.4))/(swc_l**2)

# %%
#DataFrame Sandstone
dfS = pd.DataFrame({'Porosity':phi_s , 'Swc':swc_s, 'Permeability(mD)':k_s})
dfS['label'] = 1
label_s = np.array(dfS['label'])
dfS['lithology'] = "Sandstone"
lithologyS = np.array(dfS['lithology'])
dfS
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 0    0.245868  0.112151          1.422408      1  Sandstone
# 1    0.243809  0.122600          1.147047      1  Sandstone
# 2    0.262575  0.082772          3.487318      1  Sandstone
# 3    0.271057  0.097222          2.907206      1  Sandstone
# 4    0.254705  0.115847          1.557162      1  Sandstone
# ..        ...       ...               ...    ...        ...
# 295  0.244910  0.116908          1.286701      1  Sandstone
# 296  0.238630  0.083621          2.243383      1  Sandstone
# 297  0.253507  0.099704          2.059068      1  Sandstone
# 298  0.251066  0.093898          2.224833      1  Sandstone
# 299  0.248870  0.096695          2.018414      1  Sandstone
#
# [300 rows x 5 columns]

# %%
#DataFrame Limestone
dfL = pd.DataFrame({'Porosity':phi_l , 'Swc':swc_l, 'Permeability(mD)':k_l})
dfL['label'] = 0
label_l = np.array(dfL['label'])
dfL['lithology'] = "Limestone"
lithologyL = np.array(dfL['lithology'])
dfL
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 0    0.197353  0.106519          0.599454      0  Limestone
# 1    0.193747  0.102884          0.592477      0  Limestone
# 2    0.217623  0.097346          1.103577      0  Limestone
# 3    0.197849  0.093482          0.786963      0  Limestone
# 4    0.198677  0.105720          0.626715      0  Limestone
# ..        ...       ...               ...    ...        ...
# 295  0.205852  0.094922          0.908759      0  Limestone
# 296  0.207404  0.096656          0.905894      0  Limestone
# 297  0.185170  0.102502          0.489084      0  Limestone
# 298  0.199181  0.105678          0.634250      0  Limestone
# 299  0.199481  0.089231          0.895527      0  Limestone
#
# [300 rows x 5 columns]

# %%
df =pd.concat([dfL,dfS])

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 0    0.197353  0.106519          0.599454      0  Limestone
# 1    0.193747  0.102884          0.592477      0  Limestone
# 2    0.217623  0.097346          1.103577      0  Limestone
# 3    0.197849  0.093482          0.786963      0  Limestone
# 4    0.198677  0.105720          0.626715      0  Limestone
# ..        ...       ...               ...    ...        ...
# 295  0.244910  0.116908          1.286701      1  Sandstone
# 296  0.238630  0.083621          2.243383      1  Sandstone
# 297  0.253507  0.099704          2.059068      1  Sandstone
# 298  0.251066  0.093898          2.224833      1  Sandstone
# 299  0.248870  0.096695          2.018414      1  Sandstone
#
# [600 rows x 5 columns]

# %%
df = df.sample(frac = 1)

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 124  0.190078  0.092137          0.679165      0  Limestone
# 56   0.244917  0.126059          1.106828      1  Sandstone
# 40   0.196886  0.112073          0.535893      0  Limestone
# 10   0.259462  0.109504          1.890612      1  Sandstone
# 197  0.254959  0.090500          2.562815      1  Sandstone
# ..        ...       ...               ...    ...        ...
# 102  0.257616  0.096492          2.359600      1  Sandstone
# 112  0.243717  0.088121          2.216573      1  Sandstone
# 104  0.195766  0.107526          0.567742      0  Limestone
# 222  0.257236  0.108566          1.851871      1  Sandstone
# 209  0.245138  0.090446          2.158602      1  Sandstone
#
# [600 rows x 5 columns]

# %%
df = df.reset_index()

# %%
df
# Out:
#      index  Porosity       Swc  Permeability(mD)  label  lithology
# 0      124  0.190078  0.092137          0.679165      0  Limestone
# 1       56  0.244917  0.126059          1.106828      1  Sandstone
# 2       40  0.196886  0.112073          0.535893      0  Limestone
# 3       10  0.259462  0.109504          1.890612      1  Sandstone
# 4      197  0.254959  0.090500          2.562815      1  Sandstone
# ..     ...       ...       ...               ...    ...        ...
# 595    102  0.257616  0.096492          2.359600      1  Sandstone
# 596    112  0.243717  0.088121          2.216573      1  Sandstone
# 597    104  0.195766  0.107526          0.567742      0  Limestone
# 598    222  0.257236  0.108566          1.851871      1  Sandstone
# 599    209  0.245138  0.090446          2.158602      1  Sandstone
#
# [600 rows x 6 columns]

# %%
df = df.drop("index",axis =1)

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 0    0.190078  0.092137          0.679165      0  Limestone
# 1    0.244917  0.126059          1.106828      1  Sandstone
# 2    0.196886  0.112073          0.535893      0  Limestone
# 3    0.259462  0.109504          1.890612      1  Sandstone
# 4    0.254959  0.090500          2.562815      1  Sandstone
# ..        ...       ...               ...    ...        ...
# 595  0.257616  0.096492          2.359600      1  Sandstone
# 596  0.243717  0.088121          2.216573      1  Sandstone
# 597  0.195766  0.107526          0.567742      0  Limestone
# 598  0.257236  0.108566          1.851871      1  Sandstone
# 599  0.245138  0.090446          2.158602      1  Sandstone
#
# [600 rows x 5 columns]

# %%
sns.scatterplot(data=df,x='Porosity',y= 'Permeability(mD)' , hue='label')
# Out:
# <Axes: xlabel='Porosity', ylabel='Permeability(mD)'>

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 0    0.190078  0.092137          0.679165      0  Limestone
# 1    0.244917  0.126059          1.106828      1  Sandstone
# 2    0.196886  0.112073          0.535893      0  Limestone
# 3    0.259462  0.109504          1.890612      1  Sandstone
# 4    0.254959  0.090500          2.562815      1  Sandstone
# ..        ...       ...               ...    ...        ...
# 595  0.257616  0.096492          2.359600      1  Sandstone
# 596  0.243717  0.088121          2.216573      1  Sandstone
# 597  0.195766  0.107526          0.567742      0  Limestone
# 598  0.257236  0.108566          1.851871      1  Sandstone
# 599  0.245138  0.090446          2.158602      1  Sandstone
#
# [600 rows x 5 columns]

# %%
X = np.array([df['Porosity'] , df['Permeability(mD)'],df["Swc"]])

# %%
y = np.array(df['label']).reshape(1,600)

# %%
X.shape
# Out:
# (3, 600)

# %%
y.shape
# Out:
# (1, 600)

# %%
def sigma(z):

    s = 1/(1+np.exp(-z))

    return s

# %%
def intialize(X):
    n = X.shape[0]

    w = np.random.randn(n,1)
    b = 0

    return w,b

# %%
def fpropagate(X,w,b):

    Z = np.dot(w.T, X) + b 

    A = sigma(Z)

    return A

# %%
def cost(X,y,w,b):

    A = fpropagate(X,w,b)

    L = y*np.log(A) + (1-y)*np.log(1-A)

    m = X.shape[1]

    J = (-1/m)*np.sum(L)

    return J

# %%
def gradient(X,y,w,b):
    
    #A ==> (1,m) <== Y
    #dw = dj/dw ==> (2,1)
    #X ==> (2,m)
    #dw ==> (2,m).(m,1)
    
    m = X.shape[1]
    
#     w,b = initialize(X)
    
    A = fpropagate(X,w,b)
    
    #dJ/dw
    dw = (1/m)*np.dot(X, (A - y).T)
    
    #dJ/db
    db = (1/m)*np.sum(A-y)
    
    return dw , db

# %%
def backprop(X,y,w,b,epoch):
    m = X.shape[1]

    a = 0.05

    for i in range(epoch):
        dw,db = gradient(X,y,w,b)

        w = w -a*dw
        b = b -a*db 

    w_final =w
    b_final = b

    return w_final, b_final

# %%
w,b = intialize(X)

# %%
w
# Out:
# array([[-1.01925314],
#        [-0.08552767],
#        [ 0.00912095]])

# %%
b
# Out:
# 0

# %%
wf, bf = backprop(X,y,w,b,100000)

# %%
wf
# Out:
# array([[2.4798287 ],
#        [8.75116534],
#        [3.49548798]])

# %%
bf
# Out:
# np.float64(-12.12206058225182)

# %%
def predict(X,w=wf,b=bf):
    yp = np.zeros((1,600))

    Z = np.dot(w.T,X)+b 

    A = sigma(Z)

    for i in range(600):

        if A[0,i] >=0.5:
            yp[0,i] = 1
        else:
            yp[0,i] = 0 
    
    return yp

# %%
yp = predict(X)

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology
# 0    0.195937  0.080444          1.018267      0  Limestone
# 1    0.193941  0.098052          0.655195      0  Limestone
# 2    0.252224  0.104192          1.843887      1  Sandstone
# 3    0.246347  0.102894          1.704368      1  Sandstone
# 4    0.238961  0.067768          3.436524      1  Sandstone
# ..        ...       ...               ...    ...        ...
# 595  0.206957  0.097644          0.879254      0  Limestone
# 596  0.248123  0.115242          1.402353      1  Sandstone
# 597  0.256230  0.109809          1.779235      1  Sandstone
# 598  0.259273  0.111492          1.817943      1  Sandstone
# 599  0.194469  0.090830          0.772719      0  Limestone
#
# [600 rows x 5 columns]

# %%
df["predicted_y"] = yp.reshape(-1,1)

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology  predicted_y
# 0    0.195937  0.080444          1.018267      0  Limestone          0.0
# 1    0.193941  0.098052          0.655195      0  Limestone          0.0
# 2    0.252224  0.104192          1.843887      1  Sandstone          1.0
# 3    0.246347  0.102894          1.704368      1  Sandstone          1.0
# 4    0.238961  0.067768          3.436524      1  Sandstone          1.0
# ..        ...       ...               ...    ...        ...          ...
# 595  0.206957  0.097644          0.879254      0  Limestone          0.0
# 596  0.248123  0.115242          1.402353      1  Sandstone          1.0
# 597  0.256230  0.109809          1.779235      1  Sandstone          1.0
# 598  0.259273  0.111492          1.817943      1  Sandstone          1.0
# 599  0.194469  0.090830          0.772719      0  Limestone          0.0
#
# [600 rows x 6 columns]

# %%
plt.figure(figsize=(10,8))
plt.scatter(df.index,df["label"],s = 0.8)
plt.scatter(df.index,df["predicted_y"],s = 0.8,alpha = 0.7)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(df["label"],df["predicted_y"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       300
#            1       0.95      0.97      0.96       300
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.96      0.96      0.96       600

# %% [markdown]
# ### With scikit learn

# %%
from sklearn.linear_model import LogisticRegression

# %%
model  = LogisticRegression()

# %%
df.head()
# Out:
#    Porosity       Swc  Permeability(mD)  label  lithology  predicted_y
# 0  0.195937  0.080444          1.018267      0  Limestone          0.0
# 1  0.193941  0.098052          0.655195      0  Limestone          0.0
# 2  0.252224  0.104192          1.843887      1  Sandstone          1.0
# 3  0.246347  0.102894          1.704368      1  Sandstone          1.0
# 4  0.238961  0.067768          3.436524      1  Sandstone          1.0

# %%
Xt = df[['Porosity' , 'Permeability(mD)',"Swc"]] 

yt = df['label']

# %%
sns.scatterplot(data=df,x='Porosity',y= 'Permeability(mD)' , hue='label')
# Out:
# <Axes: xlabel='Porosity', ylabel='Permeability(mD)'>

# %%
model.fit(Xt,yt)
# Out:
# LogisticRegression()

# %%
model.predict([[0.25,1.71,0.11]])
# Out:
# c:\Users\Z004ET6Z\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
yp = predict(X)

# %%
yp.shape
# Out:
# (1, 600)

# %%
df.shape
# Out:
# (600, 6)

# %%
df["Predict_sk"] = yp.reshape(600,1)

# %%
df
# Out:
#      Porosity       Swc  Permeability(mD)  label  lithology  predicted_y  \
# 0    0.195937  0.080444          1.018267      0  Limestone          0.0
# 1    0.193941  0.098052          0.655195      0  Limestone          0.0
# 2    0.252224  0.104192          1.843887      1  Sandstone          1.0
# 3    0.246347  0.102894          1.704368      1  Sandstone          1.0
# 4    0.238961  0.067768          3.436524      1  Sandstone          1.0
# ..        ...       ...               ...    ...        ...          ...
# 595  0.206957  0.097644          0.879254      0  Limestone          0.0
# 596  0.248123  0.115242          1.402353      1  Sandstone          1.0
# 597  0.256230  0.109809          1.779235      1  Sandstone          1.0
# 598  0.259273  0.111492          1.817943      1  Sandstone          1.0
# 599  0.194469  0.090830          0.772719      0  Limestone          0.0
#
#      Predict_sk
# 0           0.0
# 1           0.0
# 2           1.0
# 3           1.0
# 4           1.0
# ..          ...
# 595         0.0
# 596         1.0
# 597         1.0
# 598         1.0
# 599         0.0
#
# [600 rows x 7 columns]

# %%
print(classification_report(df["label"],df["Predict_sk"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       300
#            1       0.95      0.97      0.96       300
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.96      0.96      0.96       600

# %% [markdown]
# ## KNN Training

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(Xt,yt)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
###accuracy
knn.score(Xt,yt)
# Out:
# 1.0

# %%
Xt.head()
# Out:
#    Porosity  Permeability(mD)       Swc
# 0  0.195937          1.018267  0.080444
# 1  0.193941          0.655195  0.098052
# 2  0.252224          1.843887  0.104192
# 3  0.246347          1.704368  0.102894
# 4  0.238961          3.436524  0.067768

# %%
knn.predict([[0.19,1.02,0.08]])
# Out:
# c:\Users\Z004ET6Z\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
k_range = range(1,20)

# %%
k_range
# Out:
# range(1, 20)

# %%
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(Xt,yt)
    scores.append(knn.score(Xt,yt))

# %%
plt.figure(figsize=(7,5))
plt.xlabel("Number of Nearest Neigbours points used for K hyperparameter")
plt.ylabel("Accuracy")
plt.plot(k_range,scores, marker = "x",color = "red")
plt.grid()
plt.xticks([0,5,10,15,20]);

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
treeclf = DecisionTreeClassifier()

# %%
treeclf.fit(Xt,yt)
# Out:
# DecisionTreeClassifier()

# %%
Xt
# Out:
#      Porosity  Permeability(mD)       Swc
# 0    0.190078          0.679165  0.092137
# 1    0.244917          1.106828  0.126059
# 2    0.196886          0.535893  0.112073
# 3    0.259462          1.890612  0.109504
# 4    0.254959          2.562815  0.090500
# ..        ...               ...       ...
# 595  0.257616          2.359600  0.096492
# 596  0.243717          2.216573  0.088121
# 597  0.195766          0.567742  0.107526
# 598  0.257236          1.851871  0.108566
# 599  0.245138          2.158602  0.090446
#
# [600 rows x 3 columns]

# %%
from sklearn import tree

# %%
from sklearn.tree import export_graphviz
export_graphviz(
                treeclf,
                out_file="t.dot",
                feature_names=["Porosity","Permeability","Saturation"],
                class_names=["Limestone","Sandstone"],
                rounded=True,
                filled=True
                )

# %%
tree.plot_tree(treeclf)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[0] <= 0.221\ngini = 0.5\nsamples = 600\nvalue = [300, 300]'),
#  Text(0.2, 0.75, 'gini = 0.0\nsamples = 296\nvalue = [296, 0]'),
#  Text(0.30000000000000004, 0.8333333333333333, 'True  '),
#  Text(0.6, 0.75, 'x[0] <= 0.229\ngini = 0.026\nsamples = 304\nvalue = [4, 300]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.4, 0.5833333333333334, 'x[2] <= 0.095\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.2, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6, 0.4166666666666667, 'x[1] <= 1.088\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.4, 0.25, 'x[2] <= 0.11\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8, 0.5833333333333334, 'gini = 0.0\nsamples = 295\nvalue = [0, 295]')]

# %%
import pydotplus
from IPython.display import Image  
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz

# Export the decision tree to a dot file
export_graphviz(
    treeclf,
    out_file="t.dot",
    feature_names=["Porosity", "Permeability", "Saturation"],
    class_names=["Limestone", "Sandstone"],
    rounded=True,
    filled=True
)

# Read and display the dot file
with open("t.dot") as f:
    dot_graph = f.read()

# Use pydotplus to create a graph from the dot data
graph = pydotplus.graph_from_dot_data(dot_graph)
plt.imshow(Image(graph.create_png()))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[35], line 22
#      20 # Use pydotplus to create a graph from the dot data
#      21 graph = pydotplus.graph_from_dot_data(dot_graph)
# ---> 22 plt.imshow(Image(graph.create_png()))
#      23 plt.axis('off')
#      24 plt.show()
#
# File c:\Users\Z004ET6Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pydotplus\graphviz.py:1797, in Dot.__init__.<locals>.<lambda>(f, prog)
#    1792 # Automatically creates all the methods enabling the creation
#    1793 # of output in any of the supported formats.
#    1794 for frmt in self.formats:
#    1795     self.__setattr__(
#    1796         'create_' + frmt,
# -> 1797         lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798     )
#    1799     f = self.__dict__['create_' + frmt]
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#
# File c:\Users\Z004ET6Z\AppData\Local\Programs\Python\Python310\lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

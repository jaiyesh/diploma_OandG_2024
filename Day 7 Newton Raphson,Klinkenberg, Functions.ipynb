# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Example 1: Square of a Number using Newton Raphson Method

# %%
abs(-45)
# Out:
# 45

# %%
abs(45)
# Out:
# 45

# %%
n = float(input("Hey, Enter your number to be Square-Rooted: "))

x_0 = float(input("Hey, Enter the Initial Guess of the root: "))


x = x_0

count = 0
print(f"The value of x_{count} is {x}")

while (abs(x**2 - n)>0.0000001):
    print("=======================")
    x = x - ((x**2 - n)/(2*x))
    count = count+1
    print(f"The value of x_{count} is {x}")
    

print(f"\n \n Result: The square root of {n} is {x}")
print(f"\n \n The Actual Square Root of {n} is {n**0.5}")
print(f'\n The num of iterations used = {count}')
# Out:
# Hey, Enter your number to be Square-Rooted: 56678956
# Hey, Enter the Initial Guess of the root: 2
# The value of x_0 is 2.0
# =======================
# The value of x_1 is 14169740.0
# =======================
# The value of x_2 is 7084871.999999858
# =======================
# The value of x_3 is 3542439.999998518
# =======================
# The value of x_4 is 1771227.9999874027
# =======================
# The value of x_5 is 885629.9998977229
# =======================
# The value of x_6 is 442846.9991787918
# =======================
# The value of x_7 is 221487.49342485724
# =======================
# The value of x_8 is 110871.69740418908
# =======================
# The value of x_9 is 55691.45476444864
# =======================
# The value of x_10 is 28354.593205892674
# =======================
# The value of x_11 is 15176.763525085444
# =======================
# The value of x_12 is 9455.675665696586
# =======================
# The value of x_13 is 7724.924344900552
# =======================
# The value of x_14 is 7531.038942228962
# =======================
# The value of x_15 is 7528.543167764277
# =======================
# The value of x_16 is 7528.542754079316
# =======================
# The value of x_17 is 7528.542754079304
#
#
#  Result: The square root of 56678956.0 is 7528.542754079304
#
#
#  The Actual Square Root of 56678956.0 is 7528.542754079304
#
#  The num of iterations used = 17

# %% [markdown]
# ## Klinkenberg
#
# k(g) = k(l) + c(1/pm)
#
# kg = measured gas permeability pm = mean pressure kL = equivalent liquid permeability, i.e., absolute permeability, k c = slope of the line
#
# c = b.k(l) = 6.9 kL^(-0.36)
#
# $ 6.9(k_l)^{0.64} + p_m * k_L - p_m * k_g = 0$  = f(k_l)
#
# f'(k_l) = 4.416*k_l^(-0.36) + p_m

# %% [markdown]
# **Example : - The permeability of a core plug is measured by air. Only one measurement is made at a mean pressure of 2.152 psi. The air permeability is 46.6 md. Estimate the absolute permeability of the core sample. Compare the result with the actual absolute permeability of 23.66 md.**

# %%
pm = 2.152

kg = 46.6

k = float(input("Enter your initial guess of absolute permeability kl: "))


count = 0
print(f"The value of kl_{count} is {k}")

while (abs(6.9*(k**0.64)+pm*k-pm*kg)>0.000000000001):
    print("=======================")
    updated_value = (6.9*(k**0.64)+pm*k-pm*kg)/(4.416*(k**(-0.36)) + pm) #f(k_l)/f'(k_l)
    k = k - updated_value
    count = count+1
    print(f"The value of kl_{count} is {k}")
    

print(f"The final value of Perm K is : {k}")
print(f"The Actual value of Perm K is : {23.66}")

print(f"The % Error is : {100*abs((k-23.66)/k)}")
# Out:
# Enter your initial guess of absolute permeability kl: 50
# The value of kl_0 is 50.0
# =======================
# The value of kl_1 is 21.63092703566329
# =======================
# The value of kl_2 is 22.844134695246225
# =======================
# The value of kl_3 is 22.84900220489256
# =======================
# The value of kl_4 is 22.849002279471133
# The final value of Perm K is : 22.849002279471133
# The Actual value of Perm K is : 23.66
# The % Error is : 3.549379139663855

# %%
pm = float(input("Enter the mean pressure at which permeability is measured in lab (p_m): "))

kg = float(input("Enter the gas permeability measures in lab(k_g): "))

k = float(input("Enter your initial guess of absolute permeability kl: "))


count = 0
print(f"The value of kl_{count} is {k}")

while (abs(6.9*(k**0.64)+pm*k-pm*kg)>0.000000000001):
    print("=======================")
    updated_value = (6.9*(k**0.64)+pm*k-pm*kg)/(4.416*(k**(-0.36)) + pm) #f(k_l)/f'(k_l)
    k = k - updated_value
    count = count+1
    print(f"The value of kl_{count} is {k}")
    

print(f"The final value of Perm K is : {k}")
print(f"The Actual value of Perm K is : {23.66}")

print(f"The % Error is : {100*abs((k-23.66)/k)}")

# %% [markdown]
# ## Python Functions: does some specific task for your input and return something back to you

# %%
print("Hello Ashwajeet, welcome to the class")
# Out:
# Hello Ashwajeet, welcome to the class

# %%
print("Hello Jitin, Welcome to the class")
# Out:
# Hello Jitin, Welcome to the class

# %%
print("Hello Mohammed, Welcome to the class")
# Out:
# Hello Mohammed, Welcome to the class

# %%
print("Hello Samy, Welcome to the class")
# Out:
# Hello Samy, Welcome to the class

# %%
def greet(name_of_attendees):
    print(f"Hello {name_of_attendees}, Welcome to the class")

# %%
greet("Ashwajeet")
# Out:
# Hello Ashwajeet, Welcome to the class

# %%
greet("Samy")
# Out:
# Hello Samy, Welcome to the class

# %%
def add(x,y):
    z = x+y
    print(f"Sum of {x} and {y} is {z}")

# %%
add(4,5)
# Out:
# Sum of 4 and 5 is 9

# %%
a = add(4,5)
# Out:
# Sum of 4 and 5 is 9

# %%
a

# %%
def add(x,y):
    z = x+y
    print(f"Sum of {x} and {y} is {z}")
    return z

# %%
a = add(4,5)
# Out:
# Sum of 4 and 5 is 9

# %%
a*10
# Out:
# 90

# %%
def math_op(x,y):
    add = x+y
    sub = x-y
    mul = x*y
    div = x/y
    
    return add,sub,mul,div

# %%
r = math_op(5,2)

# %%
r
# Out:
# (7, 3, 10, 2.5)

# %%
a,b,c,d = math_op(5,2)

# %%
a
# Out:
# 7

# %%
b
# Out:
# 3

# %%
c
# Out:
# 10

# %%
d
# Out:
# 2.5

# %%
a,b,c = math_op(2,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-cde8da3cc773> in <module>
# ----> 1 a,b,c = math_op(2,5)
#
# ValueError: too many values to unpack (expected 3)

# %%
a,b,c,d,e = math_op(2,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-377392d09c94> in <module>
# ----> 1 a,b,c,d,e = math_op(2,5)
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
def klinkenberg(kg,pm,k):
    
    """
    This klinkenberg function calculates absolute permeability for given gas permeability at a given mean pressure.
    
    INPUTS:
    kg=> gas permeability in lab at a given mean pressure pm
    pm => mean pressure
    k=>User initial guess for absolute perm.
    
    return:
    k=> value of absolute permeability 
    
    
    
    """
    
    count = 0
    print(f"The value of kl_{count} is {k}")

    while (abs(6.9*(k**0.64)+pm*k-pm*kg)>0.000000000001):
        print("=======================")
        updated_value = (6.9*(k**0.64)+pm*k-pm*kg)/(4.416*(k**(-0.36)) + pm) #f(k_l)/f'(k_l)
        k = k - updated_value
        count = count+1
        print(f"The value of kl_{count} is {k}")


    print(f"The final value of Perm K is : {k}")
    
    return k

# %%
abs_perm = klinkenberg(56,32,2)
# Out:
# The value of kl_0 is 2
# =======================
# The value of kl_1 is 50.45398454220078
# =======================
# The value of kl_2 is 53.25394365934433
# =======================
# The value of kl_3 is 53.254832264140724
# =======================
# The value of kl_4 is 53.25483226422596
# The final value of Perm K is : 53.25483226422596

# %%
abs_perm
# Out:
# 53.25483226422596

# %%
mo.addition(3,4)
# Out:
# 7
